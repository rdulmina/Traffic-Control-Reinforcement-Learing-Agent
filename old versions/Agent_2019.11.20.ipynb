# %%
import numpy as np
from sumolib import checkBinary
import math
import random
import time
import traci
import os
import sys
import psutil
import optparse
import keras
import tensorflow as tf 
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt

config = tf.ConfigProto()
config.gpu_options.allow_growth = True

from keras.models import Model
from keras.layers import Input,Dense,Dropout,dot,Flatten

os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz2.38/bin/'

# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'
# Out:
# Using TensorFlow backend.

# %%
class Vehicle:
    def __init__(self,vid,waiting_time,vtype):
        self.vid=vid
        self.waiting_time=waiting_time
        self.vtype=vtype

# %% [markdown]
# # Environment

# %%
class Sumo:
    
    RedYellowGreenStates=["rrgrrGGrrrgrrGGr","rGGrrrgrrGGrrrgr","rrgrrrgrrrgrGGGG","GGGGrrgrrrgrrrgr","rrgrGGGGrrgrrrgr","rrgrrrgrGGGGrrgr","GrGrrrGrGrGrrrGr","rrGrGrGrrrGrGrGr"]
    
    def __init__(self):
        self.nearby_vehicles=[[[],[],[]],[[],[],[]],[[],[],[]],[[],[],[]]]
        self.count=0
        if 'SUMO_HOME' in os.environ:
            tools=os.path.join(os.environ['SUMO_HOME'],'tools')
            sys.path.append(tools)
   
        else: 
            sys.exit("please declare environment variable 'SUMO_HOME'")
            
    def getSumoBinary(self):

        sumoBinary = checkBinary('sumo-gui')
        return sumoBinary
    
    def getState(self):
        incomming_state=np.zeros([12,3]) # definition of a one row is (number of vehicles in that lane,maximum waiting time,emergency or not)
        outgoing_state=np.ones(4) #will get the negetive impact of this [Left,Right,Bottom,Top]
        for i in range(1,5):
            for j in range(0,3):
                all_vehicles_on_lane = traci.lane.getLastStepVehicleIDs(str(i)+"si_"+str(j))
                
                for vehicle in self.nearby_vehicles[i-1][j]:
                    if vehicle.vid not in all_vehicles_on_lane:
                        nearby_vehicle_on_lane=self.nearby_vehicles[i-1][j]
                        nearby_vehicle_on_lane.remove(vehicle)
                        self.nearby_vehicles[i-1][j]=nearby_vehicle_on_lane
                        
                for vehicle_id in all_vehicles_on_lane:
#                     getLanePosition outputs the position of the vehicle with respect to start end of the lane that is not the junction side
                    if(traci.vehicle.getLanePosition(vehicle_id)>=132):# consider vehicles which is 100M near or less to the junction lan length is 232
                        flag=1
                        for e,vehicle in enumerate(self.nearby_vehicles[i-1][j]):
                            if vehicle.vid==vehicle_id:
                                vehicle.waiting_time+=1
                                vehicle_list=self.nearby_vehicles[i-1][j]
                                vehicle_list[e]=vehicle
                                self.nearby_vehicles[i-1][j]=vehicle_list
                                flag=0
                                break
                        if(flag):
                      
                            new_vehicle_obj=Vehicle(vehicle_id,0,traci.vehicle.getTypeID(vehicle_id))
                            nearby_vehicle_on_lane=self.nearby_vehicles[i-1][j]
                            nearby_vehicle_on_lane.append(new_vehicle_obj)
                            self.nearby_vehicles[i-1][j]=nearby_vehicle_on_lane
                            
                #prepairing incomming state          
                emergency=0
                maximum_waiting_time=0
                for vehicle in self.nearby_vehicles[i-1][j]:
                    if vehicle.vtype=="emergency":
                        emergency=1
                    if vehicle.waiting_time>maximum_waiting_time:
                        maximum_waiting_time=vehicle.waiting_time
                        
                #Normalizing state representation
                #maximum waiting time of a vehicle is 100s
                #maximum number of vehicles that can be fit in to 100M range is 17   
                incomming_state[j+(i-1)*3][0]=len(self.nearby_vehicles[i-1][j])/17
                
                if(maximum_waiting_time>100):
                    incomming_state[j+(i-1)*3][1]=1
                else:
                    incomming_state[j+(i-1)*3][1]=maximum_waiting_time/100
                    
                incomming_state[j+(i-1)*3][2]=emergency
                
        
            #prepairing outgoing state      
            for vehicle_id in traci.lane.getLastStepVehicleIDs(str(i)+"o_0"):
                if(traci.vehicle.getLanePosition(vehicle_id)>=386):#length of an outgoing road is 486M
                    outgoing_state[i-1]=outgoing_state[i-1]-1/17 # - because of to get the negetive impact when the road is blocked
       
            #transforming outgoing state into attention state
            outgoing_state_final=np.ones(12)
            outgoing_state_final[4]=outgoing_state_final[6]=outgoing_state_final[11]=outgoing_state[0]
            outgoing_state_final[1]=outgoing_state_final[8]=outgoing_state_final[9]=outgoing_state[1]
            outgoing_state_final[2]=outgoing_state_final[3]=outgoing_state_final[10]=outgoing_state[2]
            outgoing_state_final[0]=outgoing_state_final[5]=outgoing_state_final[7]=outgoing_state[3]
            
        return [incomming_state.reshape(1,12,3),outgoing_state_final.reshape(1,12,1)]
        
    def changePhase(self,next_phase_index):
        current_phase=traci.trafficlight.getRedYellowGreenState('0')
        next_phase=self.RedYellowGreenStates[next_phase_index]
        
        
        if(next_phase!=current_phase):#generate yellow phase
            yellow_phase=""
            for i in range(0, len(current_phase)):
                if(current_phase[i].lower()=="g" and next_phase[i].lower()=="r"):

                    yellow_phase=yellow_phase+"y"
                else:
                    yellow_phase=yellow_phase+current_phase[i]

            traci.trafficlight.setRedYellowGreenState('0',yellow_phase) #set yellow phase

            for i in range(3): # allow yellow phase for 3 seconds
                traci.simulationStep()
                
        traci.trafficlight.setRedYellowGreenState('0',next_phase)
        return
    
    def reward(self,replayMemory):
        maximum_wainting_time=0
        maximum_emergency_waiting=0
        for experiance in replayMemory.replay_buffer:
            #find the longest waiting time of a vehicle within the replay_buffer
            traffic_state=experiance[0][0][0]
        
            for lane in traffic_state:
                if lane[1]>maximum_wainting_time:
                    maximum_wainting_time=lane[1]
                if lane[2]==1:
                    if lane[1]>maximum_emergency_waiting:
                        maximum_emergency_waiting=lane[1]
                          
        reward=-(maximum_wainting_time+2*maximum_emergency_waiting)      
        return reward,maximum_wainting_time*100,maximum_emergency_waiting*100

# %% [markdown]
# # Deep Q-network

# %%
def createDQN():
    incomming_vehicles=Input(shape=(12,3))
    outgoing_vehicles=Input(shape=(12,1))
    
    Dense1_out=Dense(20,name="Dense1",activation='relu')(incomming_vehicles)
    Dense2_out=Dense(10,name="Dense2",activation='relu')(Dense1_out)
    Dropout1_out=Dropout(.2,name="Dropout1")(Dense2_out)
    Dense3_out=Dense(5,name="Dense3",activation='relu')(Dropout1_out)
    
    Dense4_out=Dense(1,name="Dense4",activation='relu')(outgoing_vehicles)
    Dot_out=dot([Dense3_out,Dense4_out],axes=1, normalize=False)
    Flatten_out=Flatten()(Dot_out)
    
    Dense5_out=Dense(8,name="Dense5")(Flatten_out)#no activation function for last layer
    
    model = Model(inputs=[incomming_vehicles,outgoing_vehicles], outputs=[Dense5_out])
    model.compile(optimizer="Adam",loss="categorical_crossentropy")
    plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
    return model

# %% [markdown]
# # Replay Memory

# %%
class ReplayMemory:
    def __init__(self,capacity):
        self.capacity=capacity
        self.replay_memory=[]
        self.push_count=0
        self.replay_buffer=[]
    #agent will only recive reaward after the end of an episode.until that we need to buffer the experience before pushing in
    #to the actual replay memory
    #all rewards of the actions within the episode will be equal to the final reward after the episode.
    #also the next state cannot be directly observerd here because it takes time for vehicles to move and actualy become another
    #state after making a decision.So when adding an experience we add next state as none and after the next action we pop the last
    #experiance and add the current state as the last experience next state.
    def addToReplayBuffuer(self,current_state,action):
        if(self.replay_buffer):
            previous_experience=self.replay_buffer.pop()# get the last experience
            previous_experience[3]=current_state #add the current state as the previous experience next state.
            self.replay_buffer.append(previous_experience)
            
        self.replay_buffer.append([current_state,action,None,None])#new experiance without reward and next state
            
    def addToReplay(self,reward):#experience =[state, action, reward, new_state]
        self.replay_buffer.pop()#top experience is useless
        while self.replay_buffer:#add all buffered experience to replay memory
            
            experience=self.replay_buffer.pop()
            experience[2]=reward #same reward will be given to all the experiences withing the episode
            if(len(self.replay_memory)<self.capacity):
                self.replay_memory.append(experience)
            else:
                # replace the oldest  experience with the new one in replay memory
                self.replay_memory[self.push_count%self.capacity]=experience
                self.push_count +=1
            
    def replay(self,replay_batch_size):

        if len(self.replay_memory) < replay_batch_size: 
            return

        replay_samples = random.sample(self.replay_memory, replay_batch_size)
        print('experience replay....')
        for sample in replay_samples:

            state, action, reward, new_state = sample
            
            target = PolicyNetwork.predict(state)
            
            Q_future = max(TargetNetwork.predict(new_state)[0])
#             print(TargetNetwork.predict(new_state)[0])
            target[0][action] = reward + Q_future * gamma
            PolicyNetwork.fit(state, target, epochs=1, verbose=0)

# %% [markdown]
# # Agent

# %%
class Agent:
    
    def __init__(self):
        self.step_number=0
        self.tau = .125
        
        
    def getAction(self,state):
        epsilon = math.exp(-1.*self.step_number*epsilon_decay)
        epsilon = max(epsilon_min, epsilon)
        self.step_number+=1
        if np.random.random() < epsilon:
            return np.random.randint(1,action_space)
        else:
            return np.argmax(PolicyNetwork.predict(state)[0])
             
    def update_target_graph(self):
        weights = PolicyNetwork.get_weights()
        target_weights =TargetNetwork.get_weights()
        for i in range(len(target_weights)):
            target_weights[i] = weights[i] * self.tau + target_weights[i] * (1 - self.tau)
        TargetNetwork.set_weights(target_weights)

# %%
action_space=8 #action is to choose next phase,agent will take an action within last 4seconds of the current phase
minimum_phase_duration=12
PolicyNetwork=createDQN()
PolicyNetwork.summary()
TargetNetwork=createDQN()
#parameaters to be tuned

gamma = 0.85
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.001
learning_rate = 0.005
tau = .125
replay_batch_size = 32
replay_memory_capacity=100000
target_update=10
decisions_per_episode=10
replay_batch_size=256
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 12, 3)        0
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 12, 20)       80          input_9[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 12, 10)       210         Dense1[0][0]
# __________________________________________________________________________________________________
# Dropout1 (Dropout)              (None, 12, 10)       0           Dense2[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# Dense3 (Dense)                  (None, 12, 5)        55          Dropout1[0][0]
# __________________________________________________________________________________________________
# Dense4 (Dense)                  (None, 12, 1)        2           input_10[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 5, 1)         0           Dense3[0][0]
#                                                                  Dense4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 5)            0           dot_5[0][0]
# __________________________________________________________________________________________________
# Dense5 (Dense)                  (None, 8)            48          flatten_5[0][0]
# ==================================================================================================
# Total params: 395
# Trainable params: 395
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Plot history

# %%
def plot(episode_count,history,ylabel,color,label):
    ax.plot(episode_count,history,color=color, label=label)
    ax.set_xlabel('number of episodes')
    ax.set_ylabel(ylabel)
    ax.set_title('Training....')
    fig.canvas.draw()

# %% [markdown]
# # Training

# %%
sumo_env=Sumo()
replayMemory=ReplayMemory(replay_memory_capacity)
agent=Agent()
traci.start([sumo_env.getSumoBinary(), "-c", "cross3ltl.sumocfg", '--start'])
count=1   
decision_count=1
episode_count=[]
regular_waiting_history=[]
emergency_waiting_history=[]
reward_history=[]
episode_no=1

while traci.simulation.getMinExpectedNumber()>0:
  
        traci.simulationStep()
        if(count==12):#agent will make a decision at the 12th second of the current phase
            current_state=sumo_env.getState()
            action=agent.getAction(current_state)
            sumo_env.changePhase(action)
          
            count=1
            
            replayMemory.addToReplayBuffuer(current_state,action)
            
            if(decision_count==decisions_per_episode):
                decision_count=1
                reward,regular_waiting,emergency_waiting=sumo_env.reward(replayMemory)
                replayMemory.addToReplay(reward)
                agent.update_target_graph()#updating target graph is performed after each episode
                episode_count.append(episode_no)
                episode_no+=1
                regular_waiting_history.append(regular_waiting)
                emergency_waiting_history.append(emergency_waiting)
                reward_history.append(reward_history)
                replayMemory.replay(replay_batch_size)#experience replay is performed after each episode
                print('regular_waiting_history : ',regular_waiting,'emergency waining time : ',emergency_waiting)
            else:
                decision_count+=1
        else:
            count+=1
            
traci.close()
# Out:
# regular_waiting_history :  6.0 emergency waining time :  0
# regular_waiting_history :  12.0 emergency waining time :  0
# regular_waiting_history :  13.0 emergency waining time :  0
# regular_waiting_history :  15.0 emergency waining time :  2.0
# regular_waiting_history :  24.0 emergency waining time :  0
# regular_waiting_history :  34.0 emergency waining time :  0
# regular_waiting_history :  37.0 emergency waining time :  28.999999999999996
# regular_waiting_history :  32.0 emergency waining time :  32.0
# regular_waiting_history :  23.0 emergency waining time :  15.0
# regular_waiting_history :  19.0 emergency waining time :  4.0
# regular_waiting_history :  20.0 emergency waining time :  1.0
# regular_waiting_history :  25.0 emergency waining time :  9.0
# regular_waiting_history :  31.0 emergency waining time :  0
# regular_waiting_history :  28.000000000000004 emergency waining time :  0
# regular_waiting_history :  24.0 emergency waining time :  0
# regular_waiting_history :  32.0 emergency waining time :  0
# regular_waiting_history :  26.0 emergency waining time :  0
# regular_waiting_history :  35.0 emergency waining time :  0
# regular_waiting_history :  42.0 emergency waining time :  0
# regular_waiting_history :  43.0 emergency waining time :  0
# regular_waiting_history :  37.0 emergency waining time :  0
# regular_waiting_history :  16.0 emergency waining time :  0
# regular_waiting_history :  21.0 emergency waining time :  6.0
# regular_waiting_history :  21.0 emergency waining time :  21.0
# regular_waiting_history :  27.0 emergency waining time :  27.0
# regular_waiting_history :  28.999999999999996 emergency waining time :  28.999999999999996
# regular_waiting_history :  24.0 emergency waining time :  4.0
# regular_waiting_history :  33.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  30.0 emergency waining time :  30.0
# experience replay....
# regular_waiting_history :  27.0 emergency waining time :  27.0
# experience replay....
# regular_waiting_history :  30.0 emergency waining time :  30.0
# experience replay....
# regular_waiting_history :  34.0 emergency waining time :  34.0
# experience replay....
# regular_waiting_history :  34.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  28.999999999999996 emergency waining time :  2.0
# experience replay....
# regular_waiting_history :  24.0 emergency waining time :  12.0
# experience replay....
# regular_waiting_history :  27.0 emergency waining time :  22.0
# experience replay....
# regular_waiting_history :  24.0 emergency waining time :  16.0
# experience replay....
# regular_waiting_history :  26.0 emergency waining time :  11.0
# experience replay....
# regular_waiting_history :  21.0 emergency waining time :  5.0
# experience replay....
# regular_waiting_history :  23.0 emergency waining time :  16.0
# experience replay....
# regular_waiting_history :  25.0 emergency waining time :  16.0
# experience replay....
# regular_waiting_history :  30.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  28.999999999999996 emergency waining time :  0
# experience replay....
# regular_waiting_history :  24.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  21.0 emergency waining time :  3.0
# experience replay....
# regular_waiting_history :  25.0 emergency waining time :  6.0
# experience replay....
# regular_waiting_history :  30.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  26.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  28.000000000000004 emergency waining time :  0
# experience replay....
# regular_waiting_history :  25.0 emergency waining time :  9.0
# experience replay....
# regular_waiting_history :  30.0 emergency waining time :  3.0
# experience replay....
# regular_waiting_history :  39.0 emergency waining time :  3.0
# experience replay....
# regular_waiting_history :  36.0 emergency waining time :  14.000000000000002
# experience replay....
# regular_waiting_history :  44.0 emergency waining time :  21.0
# experience replay....
# regular_waiting_history :  54.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  61.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  65.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  56.00000000000001 emergency waining time :  0
# experience replay....
# regular_waiting_history :  57.99999999999999 emergency waining time :  0
# experience replay....
# regular_waiting_history :  59.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  41.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  48.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  28.999999999999996 emergency waining time :  0
# experience replay....
# regular_waiting_history :  27.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  28.000000000000004 emergency waining time :  0
# experience replay....
# regular_waiting_history :  19.0 emergency waining time :  1.0
# experience replay....
# regular_waiting_history :  21.0 emergency waining time :  19.0
# experience replay....
# regular_waiting_history :  27.0 emergency waining time :  27.0
# experience replay....
# regular_waiting_history :  36.0 emergency waining time :  36.0
# experience replay....
# regular_waiting_history :  39.0 emergency waining time :  39.0
# experience replay....
# regular_waiting_history :  42.0 emergency waining time :  19.0
# experience replay....
# regular_waiting_history :  49.0 emergency waining time :  23.0
# experience replay....
# regular_waiting_history :  34.0 emergency waining time :  25.0
# experience replay....
# regular_waiting_history :  39.0 emergency waining time :  28.999999999999996
# experience replay....
# regular_waiting_history :  42.0 emergency waining time :  24.0
# experience replay....
# regular_waiting_history :  51.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  52.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  35.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  45.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  55.00000000000001 emergency waining time :  0
# experience replay....
# regular_waiting_history :  56.99999999999999 emergency waining time :  0
# experience replay....
# regular_waiting_history :  56.00000000000001 emergency waining time :  0
# experience replay....
# regular_waiting_history :  46.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  54.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  46.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  43.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  46.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  44.0 emergency waining time :  1.0
# experience replay....
# regular_waiting_history :  54.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  59.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  52.0 emergency waining time :  8.0
# experience replay....
# regular_waiting_history :  61.0 emergency waining time :  14.000000000000002
# experience replay....
# regular_waiting_history :  66.0 emergency waining time :  24.0
# experience replay....
# regular_waiting_history :  62.0 emergency waining time :  27.0
# experience replay....
# regular_waiting_history :  49.0 emergency waining time :  2.0
# experience replay....
# regular_waiting_history :  54.0 emergency waining time :  5.0
# experience replay....
# regular_waiting_history :  59.0 emergency waining time :  31.0
# experience replay....
# regular_waiting_history :  65.0 emergency waining time :  36.0
# experience replay....
# regular_waiting_history :  75.0 emergency waining time :  39.0
# experience replay....
# regular_waiting_history :  85.0 emergency waining time :  37.0
# experience replay....
# regular_waiting_history :  94.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  98.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  68.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  72.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  74.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  38.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  44.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  51.0 emergency waining time :  1.0
# experience replay....
# regular_waiting_history :  35.0 emergency waining time :  3.0
# experience replay....
# regular_waiting_history :  37.0 emergency waining time :  1.0
# experience replay....
# regular_waiting_history :  42.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  51.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  61.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  71.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  74.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  74.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  84.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  85.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  95.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  2.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  12.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  22.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  32.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  42.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# regular_waiting_history :  100.0 emergency waining time :  100.0
# experience replay....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-6b8484165bc5> in <module>
#      31                 regular_waiting_history.append(regular_waiting)
#      32                 emergency_waiting_history.append(emergency_waiting)
# ---> 33                 replayMemory.replay(replay_batch_size)#experience replay is performed after each episode
#      34                 print('regular_waiting_history : ',regular_waiting,'emergency waining time : ',emergency_waiting)
#      35             else:
#
# <ipython-input-22-7e82519b78e5> in replay(self, replay_batch_size)
#      43             state, action, reward, new_state = sample
#      44
# ---> 45             target = PolicyNetwork.predict(state)
#      46
#      47             Q_future = max(TargetNetwork.predict(new_state)[0])
#
# d:\program files\python\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# d:\program files\python\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# d:\program files\python\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# d:\program files\python\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# vehicle waiting time history
fig=plt.figure()
ax= fig.add_subplot(111)
fig.show()

plot(episode_count,regular_waiting_history,'waiting time',color='green',label='regular vehicle')
plot(episode_count,emergency_waiting_history,'waiting time',color='red',label='emergency vehicle')
fig.legend()

# %%
#reward history
fig=plt.figure()

fig.show()
#plot history
plot(episode_count,reward_history,'reward',color='blue')
